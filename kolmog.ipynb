# %%
import pandas

import matplotlib.pyplot as plt

dat = pandas.read_csv("3.csv")
dat['resistance'].plot(kind='bar')

n = 16
plt.ylim(3.093,3.986)

print(dat.resistance.describe())

dat.plot.kde()
# Out:
# count    16.000000
# mean      3.716250
# std       0.209332
# min       3.293000
# 25%       3.568500
# 50%       3.783500
# 75%       3.857250
# max       3.986000
# Name: resistance, dtype: float64
# <AxesSubplot: ylabel='Density'>

# %%
from scipy.stats import kstest
d = dat['resistance']

print(kstest(d , 'norm', (dat.mean(), dat.std())))
# Out:
# KstestResult(statistic=0.24099746371246145, pvalue=0.2650981526399534)
